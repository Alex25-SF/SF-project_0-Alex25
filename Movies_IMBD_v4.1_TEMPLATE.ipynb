# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_csv('movie_bd_v5.csv')
data.sample(5)
# Out:
#         imdb_id     budget    revenue       original_title  \
# 1464  tt0424095  149000000   64459316         Flushed Away
# 939   tt0251114   70000000   32287044           Hart's War
# 779   tt1217613   70000000  202466756  Battle: Los Angeles
# 639   tt0758774   70000000  113280098         Body of Lies
# 313   tt0365929   40000000   12206028             Whiteout
#
#                                                    cast  \
# 1464  Hugh Jackman|Kate Winslet|Ian McKellen|Jean Re...
# 939   Bruce Willis|Colin Farrell|Terrence Howard|Mar...
# 779   Aaron Eckhart|RamÃ³n RodrÃ­guez|Will Rothhaar|...
# 639   Leonardo DiCaprio|Russell Crowe|Mark Strong|Al...
# 313   Kate Beckinsale|Gabriel Macht|Tom Skerritt|Col...
#
#                    director                          tagline  \
# 1464  David Bowers|Sam Fell             Someone's Going Down
# 939          Gregory Hoblit    Beyond Courage, Beyond Honor.
# 779      Jonathan Liebesman     It's not war. It's survival.
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %%
data.describe(include = ['object'])
# Out:
#           imdb_id  original_title  \
# count        1889            1889
# unique       1889            1887
# top     tt1951266  Fantastic Four
# freq            1               2
#
#                                                      cast           director  \
# count                                                1889               1889
# unique                                               1878                957
# top     Jennifer Lawrence|Josh Hutcherson|Liam Hemswor...  Steven Soderbergh
# freq                                                    3                 13
#
#                         tagline  \
# count                      1889
# unique                     1880
# top     Inspired by True Events
# freq                          2
#
#                                                  overview  genres  \
# count                                                1889    1889
# unique                                               1889     652
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# ...

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %%
data['profit'] = data['revenue'] - data['budget'] # добавляем колонку прибыль
data
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
from datetime import datetime, date, timedelta
data['release_date'] = pd.to_datetime(data['release_date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   datetime64[ns]
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
#  14  profit                1889 non-null   int64
# ...

# %%
data
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data['release_month'] = data['release_date'].dt.month # добавляем колонку месяц релиза
data
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
# в словарь вставляем номер вопроса и ваш ответ на него
# Пример: 
answers['1'] = '2. Spider-Man 3 (tt0413300)'
# запишите свой вариант ответа
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# если ответили верно, можете добавить комментарий со значком "+"

# %%
# тут пишем ваш код для решения данного вопроса:
data.sort_values('budget', ascending=False)
# Out:
#         imdb_id     budget     revenue  \
# 723   tt1298650  380000000  1021683000
# 1669  tt0449088  300000000   961000000
# 14    tt2395427  280000000  1405035767
# 1014  tt0401729  260000000   284139100
# 380   tt0398286  260000000   591794936
# ...         ...        ...         ...
# 885   tt0283111    5000000    38275483
# 892   tt0259446    5000000   368744044
# 1071  tt2109184    5000000   142817992
# 911   tt0322802    5000000    64282312
# 1216  tt2101441    5000000    31724284
#
#                                    original_title  \
# 723   Pirates of the Caribbean: On Stranger Tides
# 1669     Pirates of the Caribbean: At World's End
# 14                        Avengers: Age of Ultron
# 1014                                  John Carter
# 380                                       Tangled
# ...                                           ...
# 885               National Lampoonâ€™s Van Wilder
# 892                      My Big Fat Greek Wedding
# ...

# %% [markdown]
# ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения
data.query('budget == 3.800000e+08')
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
# думаю логику работы с этим словарем вы уже поняли, 
# по этому не буду больше его дублировать
answers['2'] = '2. Gods and Generals (tt0279111)'

# %%
data.sort_values('runtime', ascending=False)
# Out:
#         imdb_id     budget     revenue  \
# 1157  tt0279111   56000000    12923936
# 1081  tt0167260   94000000  1118888979
# 1736  tt0462322   67000000    25037897
# 1336  tt0360717  207000000   550000000
# 504   tt0213149  140000000   449220945
# ...         ...        ...         ...
# 1408  tt0361089   35000000    19478106
# 1626  tt0299172  110000000   103951461
# 1097  tt0283426   20000000   135680000
# 930   tt0280030   20000000   109862682
# 768   tt1449283   30000000    14460000
#
#                                      original_title  \
# 1157                              Gods and Generals
# 1081  The Lord of the Rings: The Return of the King
# 1736                                     Grindhouse
# 1336                                      King Kong
# 504                                    Pearl Harbor
# ...                                             ...
# 1408                                        Valiant
# 1626                              Home on the Range
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
data.sort_values('runtime', ascending=True)
# Out:
#         imdb_id     budget     revenue  \
# 768   tt1449283   30000000    14460000
# 930   tt0280030   20000000   109862682
# 1097  tt0283426   20000000   135680000
# 1408  tt0361089   35000000    19478106
# 1626  tt0299172  110000000   103951461
# ...         ...        ...         ...
# 504   tt0213149  140000000   449220945
# 1336  tt0360717  207000000   550000000
# 1736  tt0462322   67000000    25037897
# 1081  tt0167260   94000000  1118888979
# 1157  tt0279111   56000000    12923936
#
#                                      original_title  \
# 768                                 Winnie the Pooh
# 930                            Return to Never Land
# 1097                              The Jungle Book 2
# 1408                                        Valiant
# 1626                              Home on the Range
# ...                                             ...
# 504                                    Pearl Harbor
# 1336                                      King Kong
# ...

# %%
data.query('runtime == 63.000000')
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283)'

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %%
answers['4'] = '2. 110'

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
data.runtime.median()
# Out:
# 107.0

# %%
answers['5'] = '1. 107'

# %%
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107'}

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
data.sort_values('profit', ascending=False)
# Out:
#         imdb_id     budget     revenue                original_title  \
# 239   tt0499549  237000000  2781505847                        Avatar
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 0     tt0369610  150000000  1513528810                Jurassic World
# 4     tt2820852  190000000  1506249360                     Furious 7
# 970   tt0848228  220000000  1519557910                  The Avengers
# ...         ...        ...         ...                           ...
# 1464  tt0424095  149000000    64459316                  Flushed Away
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 1616  tt0318974  145000000    25819961                     The Alamo
# 1245  tt1210819  255000000    89289910               The Lone Ranger
#
#                                                    cast  \
# 239   Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# ...

# %%
answers['6'] = '5. Avatar (tt0499549)'

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
data.sort_values('profit', ascending=True)
# Out:
#         imdb_id     budget     revenue                original_title  \
# 1245  tt1210819  255000000    89289910               The Lone Ranger
# 1616  tt0318974  145000000    25819961                     The Alamo
# 809   tt1305591  150000000    38992758               Mars Needs Moms
# 958   tt0180052  100000000     7103973  The Adventures of Pluto Nash
# 1464  tt0424095  149000000    64459316                  Flushed Away
# ...         ...        ...         ...                           ...
# 970   tt0848228  220000000  1519557910                  The Avengers
# 4     tt2820852  190000000  1506249360                     Furious 7
# 0     tt0369610  150000000  1513528810                Jurassic World
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 239   tt0499549  237000000  2781505847                        Avatar
#
#                                                    cast  \
# 1245  Johnny Depp|Armie Hammer|William Fichtner|Hele...
# ...

# %%
answers['7'] = '5. The Lone Ranger (tt1210819)'

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
data[data['profit'] > 0]
# Out:
#         imdb_id     budget     revenue                original_title  \
# 0     tt0369610  150000000  1513528810                Jurassic World
# 1     tt1392190  150000000   378436354            Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                     Insurgent
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                     Furious 7
# ...         ...        ...         ...                           ...
# 1871  tt0171433   30000000    37036004             Keeping the Faith
# 1875  tt0219854   65000000    69700000                       The Kid
# 1877  tt0199725   20000000    27728118             Love & Basketball
# 1883  tt0122459   24000000    36609995                  Return to Me
# 1884  tt0120903   75000000   157299717                         X-Men
#
#                                                    cast  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# ...

# %%
answers['8'] = '1. 1478'

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
data_2008 = data[data['release_year'] == 2008]
data_2008.sort_values('revenue', ascending=False)
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 603  tt0367882  185000000   786636033
# 606  tt0441773  130000000   631744560
# 621  tt0448157  150000000   624029371
# 607  tt0795421   52000000   609841637
# ..         ...        ...         ...
# 708  tt0486674   25000000     6673422
# 673  tt0800241   15000000     5926410
# 702  tt0844286   20000000     5530764
# 711  tt0805570   15000000     3533227
# 712  tt0490181    8000000     2033165
#
#                                         original_title  \
# 599                                    The Dark Knight
# 603  Indiana Jones and the Kingdom of the Crystal S...
# 606                                      Kung Fu Panda
# 621                                            Hancock
# 607                                         Mamma Mia!
# ..                                                 ...
# 708                                 What Just Happened
# ...

# %%
answers['9'] = '4. The Dark Knight (tt0468569)'

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
data_2012_2014 = data[(data['release_year'] > 2011) & (data['release_year'] < 2015)]
data_2012_2014.sort_values('profit', ascending=True)
# Out:
#         imdb_id     budget     revenue                   original_title  \
# 1245  tt1210819  255000000    89289910                  The Lone Ranger
# 1214  tt0790736  130000000    61648500                         R.I.P.D.
# 1007  tt1374992   60000000     8106475                      Upside Down
# 1302  tt0884726   70000000    18662027  Legends of Oz: Dorothy's Return
# 1235  tt1308729   55000000     9489829               Bullet to the Head
# ...         ...        ...         ...                              ...
# 1189  tt1690953   76000000   970761885                  Despicable Me 2
# 974   tt1074638  200000000  1108561013                          Skyfall
# 1180  tt1300854  200000000  1215439994                       Iron Man 3
# 1177  tt2294629  150000000  1274219009                           Frozen
# 970   tt0848228  220000000  1519557910                     The Avengers
#
#                                                    cast  \
# ...

# %%
answers['10'] = '5. The Lone Ranger (tt1210819)'
answers
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107',
#  '6': '5. Avatar (tt0499549)',
#  '7': '5. The Lone Ranger (tt1210819)',
#  '8': '1. 1478',
#  '9': '4. The Dark Knight (tt0468569)',
#  '10': '5. The Lone Ranger (tt1210819)'}

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

# %%
data.genres.unique()
# Out:
# array(['Action|Adventure|Science Fiction|Thriller',
#        'Adventure|Science Fiction|Thriller',
#        'Action|Adventure|Science Fiction|Fantasy',
#        'Action|Crime|Thriller', 'Western|Drama|Adventure|Thriller',
#        'Science Fiction|Action|Thriller|Adventure',
#        'Drama|Adventure|Science Fiction',
#        'Family|Animation|Adventure|Comedy', 'Comedy|Animation|Family',
#        'Action|Adventure|Crime',
#        'Science Fiction|Fantasy|Action|Adventure',
#        'Drama|Science Fiction', 'Action|Comedy|Science Fiction',
#        'Action|Adventure|Science Fiction', 'Crime|Drama|Mystery|Western',
#        'Crime|Action|Thriller', 'Science Fiction|Action|Adventure',
#        'Romance|Fantasy|Family|Drama', 'War|Adventure|Science Fiction',
#        'Action|Family|Science Fiction|Adventure|Mystery', 'Action|Drama',
#        'Action|Drama|Thriller', 'Drama|Romance', 'Comedy|Drama', 'Action',
#        'Comedy', 'Crime|Comedy|Action|Adventure',
# ...

# %%
data11 = data.copy()
data11['genres'] = data11.genres.str.split('|') # в колонке'genres' делаем списки
data11 = data11.explode('genres') # в колонке'genres' списки делим построчно
data11.genres.value_counts() # считаем количество
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genres, dtype: int64

# %%
answers['11'] = '3. Drama'

# %%
data11 = data.copy()
data11['genres'] = data11.genres.str.split('|')
data11 = data11.explode('genres')
data11
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# ...         ...        ...         ...                                   ...
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
data12 = data11[data11['profit'] > 0]
data12
# Out:
#         imdb_id     budget     revenue      original_title  \
# 0     tt0369610  150000000  1513528810      Jurassic World
# 0     tt0369610  150000000  1513528810      Jurassic World
# 0     tt0369610  150000000  1513528810      Jurassic World
# 0     tt0369610  150000000  1513528810      Jurassic World
# 1     tt1392190  150000000   378436354  Mad Max: Fury Road
# ...         ...        ...         ...                 ...
# 1883  tt0122459   24000000    36609995        Return to Me
# 1883  tt0122459   24000000    36609995        Return to Me
# 1884  tt0120903   75000000   157299717               X-Men
# 1884  tt0120903   75000000   157299717               X-Men
# 1884  tt0120903   75000000   157299717               X-Men
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
data12.genres.value_counts()
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %%
answers['12'] = '1. Drama'

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сборы?

# %%
data.director.unique()
# Out:
# array(['Colin Trevorrow', 'George Miller', 'Robert Schwentke',
#        'J.J. Abrams', 'James Wan', 'Alejandro GonzÃ¡lez IÃ±Ã¡rritu',
#        'Alan Taylor', 'Ridley Scott', 'Kyle Balda|Pierre Coffin',
#        'Pete Docter', 'Sam Mendes', 'Lana Wachowski|Lilly Wachowski',
#        'Alex Garland', 'Chris Columbus', 'Joss Whedon',
#        'Quentin Tarantino', 'Olivier Megaton', 'Peyton Reed',
#        'Kenneth Branagh', 'Francis Lawrence', 'Brad Bird',
#        'Antoine Fuqua', 'Brad Peyton', 'Sam Taylor-Johnson', 'Adam McKay',
#        'Christopher McQuarrie', 'Seth MacFarlane', 'Matthew Vaughn',
#        'Tom McCarthy', 'Wes Ball', 'Neill Blomkamp', 'Elizabeth Banks',
#        'Steven Spielberg', 'Rob Letterman', 'Lenny Abrahamson',
#        'Peter Sohn', 'Jaume Collet-Serra', 'John Crowley', 'F. Gary Gray',
#        'Breck Eisner', 'Guy Ritchie', 'Lee Toland Krieger',
#        'Ilya Naishuller', 'Tim Johnson', 'Jake Schreier', 'Todd Haynes',
# ...

# %%
data13 = data.copy()
data13['director'] = data13.director.str.split('|')
data13 = data13.explode('director')
data13
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data13.groupby(['director'])['revenue'].sum().sort_values(ascending=False)
# Out:
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 997, dtype: int64

# %%
answers['13'] = '5. Peter Jackson'

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
data14 = data13.copy()
data14['genres'] = data14.genres.str.split('|')
data14 = data14.explode('genres')
data14
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# ...         ...        ...         ...                                   ...
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data14 = data14[data14['genres'] == 'Action']
data14.director.value_counts()
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Neil Burger           1
# Terry Gilliam         1
# Frank Coraci          1
# Steven Brill          1
# Wayne Kramer          1
# Name: director, Length: 364, dtype: int64

# %%
answers['14'] = '3. Robert Rodriguez'

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
data15 = data.copy()
data15['cast'] = data15.cast.str.split('|')
data15 = data15.explode('cast')
data15 = data15[data15['release_year'] == 2012]
data15
# Out:
#         imdb_id     budget     revenue          original_title  \
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# 970   tt0848228  220000000  1519557910            The Avengers
# ...         ...        ...         ...                     ...
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
# 1080  tt2215719   12000000    32726956  Katy Perry: Part of Me
#
#                     cast                   director  \
# 970    Robert Downey Jr.                Joss Whedon
# 970          Chris Evans                Joss Whedon
# ...

# %%
data15 = data.copy()
data15['cast'] = data15.cast.str.split('|')
data15 = data15.explode('cast')
data15 = data15[data15['release_year'] == 2012]
data15.groupby(['cast'])['revenue'].sum().sort_values(ascending=False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %%
answers['15'] = '3. Chris Hemsworth'

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
data['budget'].mean()
# Out:
# 54310829.63843303

# %%
data16 = data.copy()
data16['cast'] = data16.cast.str.split('|')
data16 = data16.explode('cast')
data16 = data16[data16['budget'] > 54310829.63843303]
data16.cast.value_counts()
# Out:
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Tom Cruise           15
# Samuel L. Jackson    15
#                      ..
# Hayden Panettiere     1
# Andy Buckley          1
# Matthew Macfadyen     1
# Stuart Townsend       1
# Wendie Malick         1
# Name: cast, Length: 1505, dtype: int64

# %%
data16 = data.copy()
data16['cast'] = data16.cast.str.split('|')
data16 = data16.explode('cast')
data16 = data16[data16['budget'] > data['budget'].mean()]
data16.cast.value_counts()
# Out:
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Tom Cruise           15
# Samuel L. Jackson    15
#                      ..
# Hayden Panettiere     1
# Andy Buckley          1
# Matthew Macfadyen     1
# Stuart Townsend       1
# Wendie Malick         1
# Name: cast, Length: 1505, dtype: int64

# %%
answers['16'] = '3. Matt Damon'

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
data17 = data.copy()
data17['genres'] = data17.genres.str.split('|')
data17 = data17.explode('genres')
data17['cast'] = data17.cast.str.split('|')
data17 = data17.explode('cast')
data17 = data17[data17['cast'] == 'Nicolas Cage']
data17
# Out:
#         imdb_id    budget    revenue         original_title          cast  \
# 168   tt2467046  16000000   19682924            Left Behind  Nicolas Cage
# 168   tt2467046  16000000   19682924            Left Behind  Nicolas Cage
# 168   tt2467046  16000000   19682924            Left Behind  Nicolas Cage
# 276   tt0448011  50000000  155446362                Knowing  Nicolas Cage
# 276   tt0448011  50000000  155446362                Knowing  Nicolas Cage
# ...         ...       ...        ...                    ...           ...
# 1818  tt0187078  90000000  237202299  Gone In Sixty Seconds  Nicolas Cage
# 1838  tt0218967  60000000  124745083         The Family Man  Nicolas Cage
# 1838  tt0218967  60000000  124745083         The Family Man  Nicolas Cage
# 1838  tt0218967  60000000  124745083         The Family Man  Nicolas Cage
# 1838  tt0218967  60000000  124745083         The Family Man  Nicolas Cage
#
#            director                                            tagline  \
# ...

# %%
data17.genres.value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Family              3
# Mystery             3
# Animation           3
# History             2
# Romance             1
# Horror              1
# War                 1
# Name: genres, dtype: int64

# %%
data17_1 = data.copy() # ВАРИАНТ 2
data17_1['genres'] = data17_1.genres.str.split('|')
data17_1 = data17_1.explode('genres')
data17_1 = data17_1[data17_1.cast.str.contains('Nicolas Cage')]
data17_1
# Out:
#         imdb_id    budget    revenue         original_title  \
# 168   tt2467046  16000000   19682924            Left Behind
# 168   tt2467046  16000000   19682924            Left Behind
# 168   tt2467046  16000000   19682924            Left Behind
# 276   tt0448011  50000000  155446362                Knowing
# 276   tt0448011  50000000  155446362                Knowing
# ...         ...       ...        ...                    ...
# 1818  tt0187078  90000000  237202299  Gone In Sixty Seconds
# 1838  tt0218967  60000000  124745083         The Family Man
# 1838  tt0218967  60000000  124745083         The Family Man
# 1838  tt0218967  60000000  124745083         The Family Man
# 1838  tt0218967  60000000  124745083         The Family Man
#
#                                                    cast       director  \
# 168   Nicolas Cage|Chad Michael Murray|Lea Thompson|...  Vic Armstrong
# 168   Nicolas Cage|Chad Michael Murray|Lea Thompson|...  Vic Armstrong
# ...

# %%
data17_1.genres.value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Family              3
# Mystery             3
# Animation           3
# History             2
# Romance             1
# Horror              1
# War                 1
# Name: genres, dtype: int64

# %%
answers['17'] = '2. Action'
answers
# Out:
# {'11': '3. Drama',
#  '12': '1. Drama',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth',
#  '16': '3. Matt Damon',
#  '17': '2. Action'}

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
data18 = data.copy()
data18 = data18[data18.production_companies.str.contains('Paramount Pictures')]
data18.sort_values('profit', ascending=True)
# Out:
#         imdb_id     budget     revenue  \
# 925   tt0267626  100000000    35168966
# 1123  tt0300556   80000000    19480739
# 1722  tt0435705   70000000    18211013
# 1623  tt0375173   60000000    13395939
# 1631  tt0315297   50000000    25195000
# ...         ...        ...         ...
# 730   tt1229238  145000000   694713380
# 1738  tt0418279  150000000   709709780
# 603   tt0367882  185000000   786636033
# 317   tt1055369  150000000   836297228
# 828   tt1399103  195000000  1123746996
#
#                                          original_title  \
# 925                                K-19: The Widowmaker
# 1123                                           Timeline
# 1722                                               Next
# 1623                                              Alfie
# 1631                                            Twisted
# ...                                                 ...
# 730                Mission: Impossible - Ghost Protocol
# ...

# %%
data18.production_companies.unique()
# Out:
# array(['Paramount Pictures|Skydance Productions',
#        'Paramount Pictures|Plan B Entertainment|Regency Enterprises',
#        'Paramount Pictures|Skydance Productions|China Movie Channel|Bad Robot|TC Productions',
#        'Paramount Pictures|Gary Sanchez Productions|Good Universe|Red Granite Pictures',
#        'Paramount Pictures|MTV Films|Platinum Dunes|Insurge Pictures',
#        'Paramount Pictures|Blumhouse Productions',
#        'Paramount Pictures|Nickelodeon Movies|Nickelodeon Animation Studios|United Plankton Pictures|Disruption Entertainment',
#        'Paramount Pictures|Legendary Pictures|Warner Bros.|Syncopy|Lynda Obst Productions',
#        'Paramount Pictures|Nickelodeon Movies|Platinum Dunes',
#        'Paramount Pictures|Amblin Entertainment|Di Bonaventura Pictures|Platinum Dunes|Hasbro',
#        'Paramount Pictures|Metro-Goldwyn-Mayer (MGM)|Radical Studios|Flynn Picture Company',
# ...

# %%
answers['18'] = '1. K-19: The Widowmaker (tt0267626)'

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
data.groupby('release_year').sum()
# Out:
#                   budget      revenue  runtime  vote_average       profit
# release_year
# 2000          4562700000  10664099805     9956         542.5   6101399805
# 2001          5067150000  13017764865    11284         619.8   7950614865
# 2002          5134000000  14136361487    11528         653.1   9002361487
# 2003          5117300000  14346123312    10623         574.4   9228823312
# 2004          6029250000  15663430720    12014         671.3   9634180720
# 2005          6327500000  15309425558    13387         733.5   8981925558
# 2006          6083965000  14775042320    13952         775.4   8691077320
# 2007          6596495000  18162406801    14305         809.3  11565911801
# 2008          6588900000  18252781990    12979         731.1  11663881990
# 2009          6838046652  20261791024    14187         800.2  13423744372
# 2010          7540000000  21071204961    13592         762.1  13531204961
# ...

# %%
data.groupby('release_year').sum().max()
# Out:
# budget          7.970620e+09
# revenue         2.544920e+10
# runtime         1.535500e+04
# vote_average    8.685000e+02
# profit          1.866857e+10
# dtype: float64

# %%
data.groupby('release_year')['revenue'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2015    25449202382
# 2014    23405862953
# 2013    23213799791
# 2012    23079001687
# 2011    22676791872
# 2010    21071204961
# 2009    20261791024
# 2008    18252781990
# 2007    18162406801
# 2004    15663430720
# 2005    15309425558
# 2006    14775042320
# 2003    14346123312
# 2002    14136361487
# 2001    13017764865
# 2000    10664099805
# Name: revenue, dtype: int64

# %%
answers['19'] = '5. 2015'

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
data20 = data.copy()
data20 = data20[data20.production_companies.str.contains('Warner Bros')]
data20.groupby('release_year')['profit'].sum().sort_values(ascending=False)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# 2001    1343545668
# 2012    1258020056
# 2002    1022709901
# 2015     870368348
# 2006     620170743
# 2000     452631386
# Name: profit, dtype: int64

# %%
answers['20'] = '1. 2014'

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
data.release_month.value_counts()
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: release_month, dtype: int64

# %%
answers['21'] = '4. Сентябрь'

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
data22 = data.copy()
data22 = data22[(data22['release_month'] > 5) & (data22['release_month'] < 9)]
data22
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 6     tt1340138  155000000   440603537                    Terminator Genisys
# 8     tt2293640   74000000  1156730962                               Minions
# 9     tt2096673  175000000   853708609                            Inside Out
# 13    tt2120120   88000000   243637091                                Pixels
# ...         ...        ...         ...                                   ...
# 1873  tt0160009   40000000    30199105                        The Art of War
# 1875  tt0219854   65000000    69700000                               The Kid
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
answers['22'] = '2. 450'
answers
# Out:
# {'11': '3. Drama',
#  '12': '1. Drama',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth',
#  '16': '3. Matt Damon',
#  '17': '2. Action',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015',
#  '20': '1. 2014',
#  '21': '4. Сентябрь',
#  '22': '2. 450'}

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
data23 = data.copy()
data23['director'] = data23.director.str.split('|')
data23 = data23.explode('director')
data23 = data23[(data23['release_month'] < 3) | (data23['release_month'] == 12)]
data23
# Out:
#         imdb_id     budget     revenue                original_title  \
# 3     tt2488496  200000000  2068178225  Star Wars: The Force Awakens
# 5     tt1663202  135000000   532950503                  The Revenant
# 11    tt1617661  176000003   183987723             Jupiter Ascending
# 11    tt1617661  176000003   183987723             Jupiter Ascending
# 12    tt0470752   15000000    36869414                    Ex Machina
# ...         ...        ...         ...                           ...
# 1867  tt0181536   43000000    80049764             Finding Forrester
# 1872  tt0134983   90000000    14828081                     Supernova
# 1872  tt0134983   90000000    14828081                     Supernova
# 1880  tt0190374   35000000    15185241            Dungeons & Dragons
# 1887  tt0162983   40000000    36037909                    Hanging Up
#
#                                                    cast  \
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# ...

# %%
data23.director.value_counts()
# Out:
# Peter Jackson        7
# Steven Soderbergh    6
# Clint Eastwood       6
# Shawn Levy           4
# Nancy Meyers         4
#                     ..
# Tom Vaughan          1
# Peter Berg           1
# Xavier Palud         1
# John Hamburg         1
# Angelina Jolie       1
# Name: director, Length: 358, dtype: int64

# %%
answers['23'] = '5. Peter Jackson'

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
data24 = data.copy()
data24['production_companies'] = data24.production_companies.str.split('|')
data24 = data24.explode('production_companies')
data24['original_title'] = data24['original_title'].apply(lambda x: len(x))
data24
# Out:
#         imdb_id     budget     revenue  original_title  \
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# ...         ...        ...         ...             ...
# 1887  tt0162983   40000000    36037909              10
# 1887  tt0162983   40000000    36037909              10
# 1887  tt0162983   40000000    36037909              10
# 1887  tt0162983   40000000    36037909              10
# 1888  tt0163676   15000000     5217498              12
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
data24.groupby(['production_companies'])['original_title'].mean().sort_values(ascending=False)
# Out:
# production_companies
# Four By Two Productions       83.0
# Jim Henson Company, The       59.0
# Dos Corazones                 47.0
# Museum Canada Productions     46.0
# Polsky Films                  46.0
#                               ...
# Everest Entertainment          3.0
# Berlanti Productions           3.0
# XM2 Productions                2.0
# Ixtlan Productions             2.0
# Global Entertainment Group     2.0
# Name: original_title, Length: 1771, dtype: float64

# %%
answers['24'] = '5. Four By Two Productions'

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
data25 = data24.copy()
data25['overview'] = data25.overview.str.split(' ')
data25['overview'] = data25['overview'].apply(lambda x: len(x))
data25
# Out:
#         imdb_id     budget     revenue  original_title  \
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# 0     tt0369610  150000000  1513528810              14
# ...         ...        ...         ...             ...
# 1887  tt0162983   40000000    36037909              10
# 1887  tt0162983   40000000    36037909              10
# 1887  tt0162983   40000000    36037909              10
# 1887  tt0162983   40000000    36037909              10
# 1888  tt0163676   15000000     5217498              12
#
#                                                    cast         director  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  Colin Trevorrow
# ...

# %%
data25.groupby(['production_companies'])['overview'].mean().sort_values(ascending=False)
# Out:
# production_companies
# Midnight Picture Show                    175.0
# Room 9 Entertainment                     161.0
# Heineken Branded Entertainment           161.0
# 98 MPH Productions                       159.0
# Brookwell-McNamara Entertainment         156.0
#                                          ...
# London Boulevard                          13.0
# Phantom Four                              13.0
# Henceforth                                13.0
# Empire Pictures                           11.0
# Motion Picture Corporation of America     11.0
# Name: overview, Length: 1771, dtype: float64

# %%
answers['25'] = '3. Midnight Picture Show'

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
data26 = data.copy()
data26 = data26[data26['vote_average'] > data26['vote_average'].quantile(.99)]
data26
# Out:
#         imdb_id     budget     revenue  \
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 118   tt0816692  165000000   621752480
# 119   tt2015381  170000000   773312399
# 125   tt2084970   14000000   233555708
# 128   tt2267998   61000000   369330363
# 138   tt2278388   30000000   174600318
# 370   tt1375666  160000000   825500000
# 599   tt0468569  185000000  1001921825
# 872   tt0253474   35000000   120072577
# 1081  tt0167260   94000000  1118888979
# 1183  tt0993846  100000000   392000694
# 1191  tt2024544   20000000   187000000
# 1800  tt0209144    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# 118                                    Interstellar
# 119                         Guardians of the Galaxy
# 125                              The Imitation Game
# ...

# %%
data26.original_title.unique()
# Out:
# array(['Inside Out', 'Room', 'Interstellar', 'Guardians of the Galaxy',
#        'The Imitation Game', 'Gone Girl', 'The Grand Budapest Hotel',
#        'Inception', 'The Dark Knight', 'The Pianist',
#        'The Lord of the Rings: The Return of the King',
#        'The Wolf of Wall Street', '12 Years a Slave', 'Memento'],
#       dtype=object)

# %%
answers['26'] = '1. Inside Out, The Dark Knight, 12 Years a Slave'

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
data27 = data.copy()
data27['cast'] = data27.cast.str.split('|')
data27
# Out:
#         imdb_id     budget     revenue                        original_title  \
# 0     tt0369610  150000000  1513528810                        Jurassic World
# 1     tt1392190  150000000   378436354                    Mad Max: Fury Road
# 2     tt2908446  110000000   295238201                             Insurgent
# 3     tt2488496  200000000  2068178225          Star Wars: The Force Awakens
# 4     tt2820852  190000000  1506249360                             Furious 7
# ...         ...        ...         ...                                   ...
# 1884  tt0120903   75000000   157299717                                 X-Men
# 1885  tt0192255   22000000    13555988                    The Little Vampire
# 1886  tt0131704   76000000    35134820  The Adventures of Rocky & Bullwinkle
# 1887  tt0162983   40000000    36037909                            Hanging Up
# 1888  tt0163676   15000000     5217498                          The In Crowd
#
# ...

# %%
data27_1 = data27['cast']
data27_1
# Out:
# 0       [Chris Pratt, Bryce Dallas Howard, Irrfan Khan...
# 1       [Tom Hardy, Charlize Theron, Hugh Keays-Byrne,...
# 2       [Shailene Woodley, Theo James, Kate Winslet, A...
# 3       [Harrison Ford, Mark Hamill, Carrie Fisher, Ad...
# 4       [Vin Diesel, Paul Walker, Jason Statham, Miche...
#                               ...
# 1884    [Patrick Stewart, Hugh Jackman, Ian McKellen, ...
# 1885    [Richard E. Grant, Jonathan Lipnicki, Jim Cart...
# 1886    [Rene Russo, Jason Alexander, Piper Perabo, Ra...
# 1887    [Meg Ryan, Diane Keaton, Lisa Kudrow, Walter M...
# 1888    [Susan Ward, Lori Heuring, Matthew Settle, Nat...
# Name: cast, Length: 1889, dtype: object

# %%
from itertools import combinations
data27_1 = data27_1.apply(lambda x: list(combinations(x, 2)))
data27_1
# Out:
# 0       [(Chris Pratt, Bryce Dallas Howard), (Chris Pr...
# 1       [(Tom Hardy, Charlize Theron), (Tom Hardy, Hug...
# 2       [(Shailene Woodley, Theo James), (Shailene Woo...
# 3       [(Harrison Ford, Mark Hamill), (Harrison Ford,...
# 4       [(Vin Diesel, Paul Walker), (Vin Diesel, Jason...
#                               ...
# 1884    [(Patrick Stewart, Hugh Jackman), (Patrick Ste...
# 1885    [(Richard E. Grant, Jonathan Lipnicki), (Richa...
# 1886    [(Rene Russo, Jason Alexander), (Rene Russo, P...
# 1887    [(Meg Ryan, Diane Keaton), (Meg Ryan, Lisa Kud...
# 1888    [(Susan Ward, Lori Heuring), (Susan Ward, Matt...
# Name: cast, Length: 1889, dtype: object

# %%
data27_2 = data27_1.copy()
data27_2 = data27_2.explode()
data27_2
# Out:
# 0       (Chris Pratt, Bryce Dallas Howard)
# 0               (Chris Pratt, Irrfan Khan)
# 0         (Chris Pratt, Vincent D'Onofrio)
# 0             (Chris Pratt, Nick Robinson)
# 0       (Bryce Dallas Howard, Irrfan Khan)
#                        ...
# 1888         (Lori Heuring, Nathan Bexton)
# 1888           (Lori Heuring, Tess Harper)
# 1888       (Matthew Settle, Nathan Bexton)
# 1888         (Matthew Settle, Tess Harper)
# 1888          (Nathan Bexton, Tess Harper)
# Name: cast, Length: 18869, dtype: object

# %%
data27_2.value_counts()
# Out:
# (Daniel Radcliffe, Emma Watson)         8
# (Daniel Radcliffe, Rupert Grint)        8
# (Rupert Grint, Emma Watson)             7
# (Johnny Depp, Helena Bonham Carter)     6
# (Ben Stiller, Owen Wilson)              6
#                                        ..
# (Neil Patrick Harris, Anton Yelchin)    1
# (Russell Crowe, Paul Giamatti)          1
# (Bryan Cranston, David Oyelowo)         1
# (Emmy Rossum, Dash Mihok)               1
# (Robert De Niro, Al Pacino)             1
# Name: cast, Length: 18121, dtype: int64

# %%
answers['27'] = '5. Daniel Radcliffe, Rupert Grint'
answers
# Out:
# {'23': '5. Peter Jackson',
#  '24': '5. Four By Two Productions',
#  '25': '3. Midnight Picture Show',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': '5. Daniel Radcliffe, Rupert Grint'}

# %% [markdown]
# ВАРИАНТ 2

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '...', '2': '...'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
